# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash-muneshwar/Deep-learning/blob/main/iris_flower_calssifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Reading data set**

# %%
data = pd.read_csv("Iris.csv")

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data = data.drop(['Id'], axis=1)

# %%
data.shape
# Out:
# (150, 5)

# %%
data.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.Species.value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ##**Visualizing data set**

# %%
data.plot()
# Out:
# <Axes: >

# %%
data.hist(bins=50 , figsize=(20,12))
# Out:
# array([[<Axes: title={'center': 'SepalLengthCm'}>,
#         <Axes: title={'center': 'SepalWidthCm'}>],
#        [<Axes: title={'center': 'PetalLengthCm'}>,
#         <Axes: title={'center': 'PetalWidthCm'}>]], dtype=object)

# %%
import seaborn as sns

# %%
sns.pairplot(data,hue='Species')
plt.show()

# %%
data.isnull().sum()
# Out:
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
data["Species"].replace({'Iris-setosa':0 ,'Iris-versicolor':1,'Iris-virginica':2} , inplace=True )

# %%
plt.figure(figsize=[6,5])
sns.heatmap(data.corr(),annot=True ,cmap="coolwarm")
# Out:
# <Axes: >

# %%
x = data.drop(['Species'], axis=1)

# %%
x.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0            5.1           3.5            1.4           0.2
# 1            4.9           3.0            1.4           0.2
# 2            4.7           3.2            1.3           0.2
# 3            4.6           3.1            1.5           0.2
# 4            5.0           3.6            1.4           0.2

# %%
y = data['Species']

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Species, dtype: int64

# %% [markdown]
# **importing the model pre requirments :**

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y, test_size=0.2 , random_state = 32)

# %%
x_train.shape , x_test.shape
# Out:
# ((120, 4), (30, 4))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_test)

# %% [markdown]
# **Logistic Regression model**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import accuracy_score

# %%
model = LogisticRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_label = model.predict(x_test)

# %%
y_label
# Out:
# array([1, 0, 0, 2, 2, 2, 0, 0, 2, 0, 1, 2, 1, 1, 2, 2, 1, 2, 1, 0, 0, 2,
#        2, 0, 0, 1, 0, 2, 0, 0])

# %%
accuracy = accuracy_score(y_test,y_label)*100
print("the accuracy of the model is : ", accuracy , '%')
# Out:
# the accuracy of the model is :  93.33333333333333 %

# %% [markdown]
# * **using some new data**

# %%
ex = np.array([[4.7 ,	2.5	, 1.4	,0.6]])

# %%
ex = scaler.fit_transform(ex)

# %%
output = model.predict(ex)

# %%
print("model prediction : ",output)
# Out:
# model prediction :  [1]

# %% [markdown]
# **SVM model**

# %%
from sklearn import svm

# %%
svm_model = svm.SVC()
svm_model.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_predict = svm_model.predict(x_test)

# %%
y_predict
# Out:
# array([1, 0, 0, 2, 2, 2, 0, 0, 1, 0, 1, 2, 1, 1, 2, 2, 1, 2, 1, 0, 0, 2,
#        2, 0, 0, 1, 0, 2, 0, 0])

# %%
from sklearn.metrics import accuracy_score

# %%
my_accuracy = accuracy_score(y_test,y_predict)*100

# %%
print("the accuracy of svm model is : ", my_accuracy,'%')
# Out:
# the accuracy of svm model is :  96.66666666666667 %

# %% [markdown]
# **Decision tree**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc_model = DecisionTreeClassifier()
dtc_model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predection = dtc_model.predict(x_test)

# %%
predection
# Out:
# array([1, 0, 0, 2, 2, 2, 0, 0, 1, 0, 1, 2, 1, 1, 2, 2, 2, 2, 1, 0, 0, 2,
#        2, 0, 0, 1, 0, 2, 0, 0])

# %%
des_accuracy = accuracy_score(y_test,predection)*100

# %%
print("the accuracy of decision tree model is : ", des_accuracy ,'%')
# Out:
# the accuracy of decision tree model is :  93.33333333333333 %

# %% [markdown]
# **Random forest**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
forest = RandomForestClassifier()
forest.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred = forest.predict(x_test)
fore_accuracy = accuracy_score(y_test,pred)*100
print("accuracy is : ",fore_accuracy,'%')
# Out:
# accuracy is :  90.0 %

# %%
results = pd.DataFrame({
    'Model' : [
        'Logistic Regression' , 'SVM model' , 'Decision Tree' , 'Random Forest'
    ] ,
    'Accuracies' : [
        accuracy , my_accuracy, des_accuracy , fore_accuracy
    ]
})

# %%
results.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a8f56_row0_col1, #T_a8f56_row2_col1 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_a8f56_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a8f56_row3_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a8f56" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8f56_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a8f56_level0_col1" class="col_heading level0 col1" >Accuracies</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8f56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a8f56_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_a8f56_row0_col1" class="data row0 col1" >93.333333</td>
#     </tr>
#     <tr>
#       <th id="T_a8f56_level0_row1" class="row_heading level0 row1" >1</th>
# ...
