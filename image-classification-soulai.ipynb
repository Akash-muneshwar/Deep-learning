# %% [markdown]
# # Importing libraries

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Input, GlobalAveragePooling2D, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.optimizers.schedules import CosineDecay
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Data Preprocessing

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Class names for reference
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Display some sample images
plt.figure(figsize=(10,5))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_train[i])
    plt.title(class_names[y_train[i][0]])
    plt.axis('off')
plt.show()

# %%
print("Training data shape:", x_train.shape)
print("Testing data shape:", x_test.shape)
# Out:
# Training data shape: (50000, 32, 32, 3)
# Testing data shape: (10000, 32, 32, 3)

# %%
unique, counts = np.unique(y_train, return_counts=True)
plt.figure(figsize=(8, 4))
plt.bar(class_names, counts, color='skyblue')
plt.xlabel("Class")
plt.ylabel("Count")
plt.title("Class Distribution in Training Set")
plt.xticks(rotation=45)
plt.show()

# %%
x_train, x_test = x_train / 255.0, x_test / 255.0

# Convert images to TensorFlow datasets
train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).shuffle(50000).batch(64)
val_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(64)

# Data Augmentation (Improved)
train_datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2,
    shear_range=0.2,
    validation_split=0.2  # Splitting into train (80%) and validation (20%)
)

# Create train and validation generators
train_generator = train_datagen.flow(x_train, y_train, batch_size=64, subset='training')
val_generator = train_datagen.flow(x_train, y_train, batch_size=64, subset='validation')

# Convert test set to TensorFlow dataset format
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test)).batch(64)

# %% [markdown]
# # Define ResNet-18 Model with Transfer Learning

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
#pip install --upgrade tensorflow -q

# %%
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(32, 32, 3))

# Unfreeze last few layers for fine-tuning
for layer in base_model.layers[-10:]:  # Fine-tune last 10 layers
    layer.trainable = True

# Add custom layers for CIFAR-10 classification
x = GlobalAveragePooling2D()(base_model.output)
x = Dense(512, activation='relu')(x)
x = Dropout(0.3)(x)  # Adding dropout for better generalization
out = Dense(10, activation='softmax')(x)

# Create the final model
model = Model(inputs=base_model.input, outputs=out)

# Compile the model with a lower initial learning rate
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
# # Callbacks
# early_stopping = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)
# lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)

# %%
# Callbacks
early_stopping = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)

# %%
#early_stopping = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)

# %%
history = model.fit(train_generator, 
                    validation_data=val_generator, 
                    epochs=50, 
                    callbacks=[early_stopping, lr_scheduler])
# Out:
# Epoch 1/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 84s 63ms/step - accuracy: 0.3125 - loss: 2.2259 - val_accuracy: 0.0723 - val_loss: 26.6955 - learning_rate: 1.0000e-04
# Epoch 2/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.5797 - loss: 1.2223 - val_accuracy: 0.6522 - val_loss: 1.0416 - learning_rate: 1.0000e-04
# Epoch 3/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.6477 - loss: 1.0241 - val_accuracy: 0.6964 - val_loss: 0.8809 - learning_rate: 1.0000e-04
# Epoch 4/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.6894 - loss: 0.9161 - val_accuracy: 0.7110 - val_loss: 0.8438 - learning_rate: 1.0000e-04
# Epoch 5/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.7133 - loss: 0.8318 - val_accuracy: 0.7343 - val_loss: 0.7705 - learning_rate: 1.0000e-04
# Epoch 6/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.7306 - loss: 0.7805 - val_accuracy: 0.7391 - val_loss: 0.7535 - learning_rate: 1.0000e-04
# Epoch 7/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.7498 - loss: 0.7289 - val_accuracy: 0.7637 - val_loss: 0.7011 - learning_rate: 1.0000e-04
# Epoch 8/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.7578 - loss: 0.7026 - val_accuracy: 0.7596 - val_loss: 0.6984 - learning_rate: 1.0000e-04
# Epoch 9/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.7675 - loss: 0.6774 - val_accuracy: 0.7701 - val_loss: 0.6795 - learning_rate: 1.0000e-04
# Epoch 10/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 55ms/step - accuracy: 0.7799 - loss: 0.6379 - val_accuracy: 0.7739 - val_loss: 0.6610 - learning_rate: 1.0000e-04
# Epoch 11/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 53ms/step - accuracy: 0.7872 - loss: 0.6172 - val_accuracy: 0.7812 - val_loss: 0.6557 - learning_rate: 1.0000e-04
# Epoch 12/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 53ms/step - accuracy: 0.7909 - loss: 0.5997 - val_accuracy: 0.7878 - val_loss: 0.6215 - learning_rate: 1.0000e-04
# Epoch 13/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.8038 - loss: 0.5716 - val_accuracy: 0.7883 - val_loss: 0.6127 - learning_rate: 1.0000e-04
# Epoch 14/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 53ms/step - accuracy: 0.8079 - loss: 0.5574 - val_accuracy: 0.7859 - val_loss: 0.6236 - learning_rate: 1.0000e-04
# Epoch 15/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 53ms/step - accuracy: 0.8144 - loss: 0.5436 - val_accuracy: 0.7828 - val_loss: 0.6588 - learning_rate: 1.0000e-04
# Epoch 16/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 53ms/step - accuracy: 0.8230 - loss: 0.5180 - val_accuracy: 0.7913 - val_loss: 0.6082 - learning_rate: 1.0000e-04
# Epoch 17/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.8268 - loss: 0.5048 - val_accuracy: 0.7987 - val_loss: 0.5849 - learning_rate: 1.0000e-04
# Epoch 18/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.8358 - loss: 0.4808 - val_accuracy: 0.7971 - val_loss: 0.6007 - learning_rate: 1.0000e-04
# Epoch 19/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 53ms/step - accuracy: 0.8340 - loss: 0.4751 - val_accuracy: 0.7978 - val_loss: 0.6114 - learning_rate: 1.0000e-04
# Epoch 20/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8366 - loss: 0.4652
# Epoch 20: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.8366 - loss: 0.4652 - val_accuracy: 0.7930 - val_loss: 0.6279 - learning_rate: 1.0000e-04
# Epoch 21/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.8519 - loss: 0.4239 - val_accuracy: 0.8152 - val_loss: 0.5450 - learning_rate: 5.0000e-05
# Epoch 22/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 53ms/step - accuracy: 0.8641 - loss: 0.3877 - val_accuracy: 0.8218 - val_loss: 0.5432 - learning_rate: 5.0000e-05
# Epoch 23/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.8679 - loss: 0.3781 - val_accuracy: 0.8248 - val_loss: 0.5360 - learning_rate: 5.0000e-05
# Epoch 24/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.8719 - loss: 0.3646 - val_accuracy: 0.8234 - val_loss: 0.5365 - learning_rate: 5.0000e-05
# Epoch 25/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.8775 - loss: 0.3482 - val_accuracy: 0.8203 - val_loss: 0.5585 - learning_rate: 5.0000e-05
# Epoch 26/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 53ms/step - accuracy: 0.8839 - loss: 0.3371 - val_accuracy: 0.8280 - val_loss: 0.5315 - learning_rate: 5.0000e-05
# Epoch 27/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.8885 - loss: 0.3212 - val_accuracy: 0.8218 - val_loss: 0.5409 - learning_rate: 5.0000e-05
# Epoch 28/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 53ms/step - accuracy: 0.8888 - loss: 0.3170 - val_accuracy: 0.8198 - val_loss: 0.5483 - learning_rate: 5.0000e-05
# Epoch 29/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8912 - loss: 0.3092
# Epoch 29: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.8912 - loss: 0.3092 - val_accuracy: 0.8301 - val_loss: 0.5406 - learning_rate: 5.0000e-05
# Epoch 30/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 55ms/step - accuracy: 0.8992 - loss: 0.2907 - val_accuracy: 0.8364 - val_loss: 0.5084 - learning_rate: 2.5000e-05
# Epoch 31/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.9019 - loss: 0.2822 - val_accuracy: 0.8356 - val_loss: 0.5214 - learning_rate: 2.5000e-05
# Epoch 32/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.9073 - loss: 0.2623 - val_accuracy: 0.8309 - val_loss: 0.5285 - learning_rate: 2.5000e-05
# Epoch 33/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9096 - loss: 0.2584
# Epoch 33: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.9096 - loss: 0.2584 - val_accuracy: 0.8320 - val_loss: 0.5319 - learning_rate: 2.5000e-05
# Epoch 34/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.9126 - loss: 0.2496 - val_accuracy: 0.8392 - val_loss: 0.5226 - learning_rate: 1.2500e-05
# Epoch 35/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.9156 - loss: 0.2371 - val_accuracy: 0.8415 - val_loss: 0.5230 - learning_rate: 1.2500e-05
# Epoch 36/50
# 624/625 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9206 - loss: 0.2266
# Epoch 36: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.9206 - loss: 0.2266 - val_accuracy: 0.8431 - val_loss: 0.5248 - learning_rate: 1.2500e-05
# Epoch 37/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.9170 - loss: 0.2307 - val_accuracy: 0.8395 - val_loss: 0.5259 - learning_rate: 6.2500e-06
# Epoch 38/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 34s 54ms/step - accuracy: 0.9199 - loss: 0.2272 - val_accuracy: 0.8437 - val_loss: 0.5147 - learning_rate: 6.2500e-06

# %% [markdown]
# # Evaluate the Model (Metrics & Confusion Matrix)

# %%
import matplotlib.pyplot as plt

# Retrieve accuracy and loss from training history
history_dict = history.history
train_acc = history_dict['accuracy']
val_acc = history_dict['val_accuracy']
train_loss = history_dict['loss']
val_loss = history_dict['val_loss']
epochs = range(1, len(train_acc) + 1)

# Plot Training & Validation Accuracy
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(epochs, train_acc, 'b-', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r-', label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training vs. Validation Accuracy')
plt.legend()

# Plot Training & Validation Loss
plt.subplot(1, 2, 2)
plt.plot(epochs, train_loss, 'b-', label='Training Loss')
plt.plot(epochs, val_loss, 'r-', label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training vs. Validation Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %%
y_pred = np.argmax(model.predict(x_test), axis=1)

# Print classification report
print(classification_report(y_test, y_pred, target_names=class_names))

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(8,6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Save the trained model
model.save("resnet50_cifar10")
print("Model training complete! Model saved as 'resnet50_cifar10'.")
